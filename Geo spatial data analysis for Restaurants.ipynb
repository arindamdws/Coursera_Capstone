# %% [markdown]
# #### Import Libraries for data analysis and representation

# %%
import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json 
from geopy.geocoders import Nominatim 
import requests 
from pandas.io.json import json_normalize 
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium 
#!conda install -c anaconda beautifulsoup4 --yes
from  bs4 import BeautifulSoup
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Get all the files from Wikipedia that contains the postcode and neighborhood information for london area for processing

# %%
sources_E=requests.get('https://en.wikipedia.org/wiki/E_postcode_area').text
sources_EC=requests.get('https://en.wikipedia.org/wiki/EC_postcode_area').text
sources_N=requests.get('https://en.wikipedia.org/wiki/N_postcode_area').text
sources_NW=requests.get('https://en.wikipedia.org/wiki/NW_postcode_area').text
sources_SE=requests.get('https://en.wikipedia.org/wiki/SE_postcode_area').text
sources_SW=requests.get('https://en.wikipedia.org/wiki/SW_postcode_area').text
sources_W=requests.get('https://en.wikipedia.org/wiki/W_postcode_area').text
sources_WC=requests.get('https://en.wikipedia.org/wiki/WC_postcode_area').text

print("Data Requested")
# Out:
# Data Requested

# %% [markdown]
# #### Initiate the xml parser for the requested files

# %%
soup_E=BeautifulSoup(sources_E,'lxml')
soup_EC=BeautifulSoup(sources_EC,'lxml')
soup_N=BeautifulSoup(sources_N,'lxml')
soup_NW=BeautifulSoup(sources_NW,'lxml')
soup_SE=BeautifulSoup(sources_SE,'lxml')
soup_SW=BeautifulSoup(sources_SW,'lxml')
soup_W=BeautifulSoup(sources_W,'lxml')
soup_WC=BeautifulSoup(sources_WC,'lxml')

df_E=pd.DataFrame(['1']) ## This will be used to concatenate the rows during the loop introduced in the code below
df_EC=pd.DataFrame(['1']) ## This will be used to concatenate the rows during the loop introduced in the code below
df_N=pd.DataFrame(['1']) ## This will be used to concatenate the rows during the loop introduced in the code below
df_NW=pd.DataFrame(['1']) ## This will be used to concatenate the rows during the loop introduced in the code below
df_SE=pd.DataFrame(['1']) ## This will be used to concatenate the rows during the loop introduced in the code below
df_SW=pd.DataFrame(['1']) ## This will be used to concatenate the rows during the loop introduced in the code below
df_W=pd.DataFrame(['1']) ## This will be used to concatenate the rows during the loop introduced in the code below
df_WC=pd.DataFrame(['1']) ## This will be used to concatenate the rows during the loop introduced in the code below

# %% [markdown]
# # Dataframe setup for London east

# %%
#table = soup.table
df3_E=df_E
table = soup_E.find("table",{"class":"wikitable sortable"})
table_rows = table.find_all('tr')
for tr in table_rows:
    td = tr.find_all('td')
    th = tr.find_all('th')
    row_E = [i.text for i in td] 
    row1_E = [i.text for i in th]
    df_E =  pd.DataFrame(data= row1_E ,dtype='str').transpose()
    df1_E = pd.DataFrame(data= row_E ,dtype='str').transpose()
    
    #df2 = pd.array([df , df1])
    df2_E = pd.concat([df_E, df1_E], axis=1, ignore_index=True)
    df3_E = pd.concat([df2_E,df3_E])
df3_E.head()
# Out:
#        0         1                                                  2  \
# 0  E98\n  LONDON\n  Non-geographic postcode district (News Interna...
# 0  E77\n  LONDON\n  Non-geographic postcode district (NatWest, loc...
# 0  E20\n  LONDON\n  Olympic Park district: Olympic Park, & parts o...
# 0  E18\n  LONDON\n   Woodford and South Woodford district: Woodford\n
# 0  E17\n  LONDON\n  Walthamstow district: Walthamstow and Leyton (...
#
#                                                   3
# 0                                   Tower Hamlets\n
# 0                                   Tower Hamlets\n
# 0  Newham, Waltham Forest, Hackney, Tower Hamlets\n
# 0                                       Redbridge\n
# 0                                  Waltham Forest\n

# %% [markdown]
# #### Insert column header to the data frame

# %%
df3_E.columns=['PostCode District', 'PostTown','Neighborhood','Local Authority Area']
df3_E.head()
# Out:
#   PostCode District  PostTown  \
# 0             E98\n  LONDON\n
# 0             E77\n  LONDON\n
# 0             E20\n  LONDON\n
# 0             E18\n  LONDON\n
# 0             E17\n  LONDON\n
#
#                                         Neighborhood  \
# 0  Non-geographic postcode district (News Interna...
# 0  Non-geographic postcode district (NatWest, loc...
# 0  Olympic Park district: Olympic Park, & parts o...
# 0   Woodford and South Woodford district: Woodford\n
# 0  Walthamstow district: Walthamstow and Leyton (...
#
#                                Local Authority Area
# 0                                   Tower Hamlets\n
# 0                                   Tower Hamlets\n
# 0  Newham, Waltham Forest, Hackney, Tower Hamlets\n
# 0                                       Redbridge\n
# 0                                  Waltham Forest\n

# %% [markdown]
# #### Remove the line Breaks from each column

# %%
df3_E.replace({  '\n' : ''}, regex=True, inplace=True)
df3_E.shape
# Out:
# (24, 4)

# %% [markdown]
# # Dataframe setup for London east central

# %%
#table = soup.table
df3_EC=df_EC
table = soup_EC.find("table",{"class":"wikitable sortable"})
table_rows = table.find_all('tr')
for tr in table_rows:
    td = tr.find_all('td')
    th = tr.find_all('th')
    row_EC = [i.text for i in td] 
    row1_EC = [i.text for i in th]
    df_EC =  pd.DataFrame(data= row1_EC ,dtype='str').transpose()
    df1_EC = pd.DataFrame(data= row_EC ,dtype='str').transpose()
    
    #df2 = pd.array([df , df1])
    df2_EC = pd.concat([df_EC, df1_EC], axis=1, ignore_index=True)
    df3_EC = pd.concat([df2_EC,df3_EC])
df3_EC.head()
# Out:
#         0         1                2                              3
# 0  EC50\n  LONDON\n               \n               non-geographic\n
# 0  EC4Y\n  LONDON\n         Temple\n  City of London, Westminster\n
# 0  EC4V\n  LONDON\n    Blackfriars\n               City of London\n
# 0  EC4R\n  LONDON\n  Cannon Street\n               City of London\n
# 0  EC4P\n  LONDON\n               \n               non-geographic\n

# %% [markdown]
# #### Insert column header to the data frame

# %%
df3_EC.columns=['PostCode District', 'PostTown','Neighborhood','Local Authority Area']
df3_EC.head()
# Out:
#   PostCode District  PostTown     Neighborhood           Local Authority Area
# 0            EC50\n  LONDON\n               \n               non-geographic\n
# 0            EC4Y\n  LONDON\n         Temple\n  City of London, Westminster\n
# 0            EC4V\n  LONDON\n    Blackfriars\n               City of London\n
# 0            EC4R\n  LONDON\n  Cannon Street\n               City of London\n
# 0            EC4P\n  LONDON\n               \n               non-geographic\n

# %% [markdown]
# #### Remove the line Breaks from each column

# %%
df3_EC.replace({  '\n' : ''}, regex=True, inplace=True)
df3_EC.shape
# Out:
# (30, 4)

# %% [markdown]
# # Dataframe setup for London North

# %%
#table = soup.table
df3_N=df_N
table = soup_N.find("table",{"class":"wikitable sortable"})
table_rows = table.find_all('tr')
for tr in table_rows:
    td = tr.find_all('td')
    th = tr.find_all('th')
    row_N = [i.text for i in td] 
    row1_N = [i.text for i in th]
    df_N =  pd.DataFrame(data= row1_N ,dtype='str').transpose()
    df1_N = pd.DataFrame(data= row_N ,dtype='str').transpose()
    
    #df2 = pd.array([df , df1])
    df2_N = pd.concat([df_N, df1_N], axis=1, ignore_index=True)
    df3_N = pd.concat([df2_N,df3_N])
df3_N.head()
# Out:
#        0         1                                                  2  \
# 0  N81\n  LONDON\n                        Electoral Reform Services\n
# 0  N22\n  LONDON\n  Wood Green district: Wood Green, Bounds Green ...
# 0  N21\n  LONDON\n  Winchmore Hill district: Winchmore Hill, Bush ...
# 0  N20\n  LONDON\n  Whetstone district: Whetstone, Totteridge, Oak...
# 0  N19\n  LONDON\n  Upper Holloway district: Upper Holloway, Archw...
#
#                      3
# 0     non-geographic\n
# 0  Haringey, Enfield\n
# 0            Enfield\n
# 0             Barnet\n
# 0  Islington, Camden\n

# %% [markdown]
# #### Insert column header to the data frame

# %%
df3_N.columns=['PostCode District', 'PostTown','Neighborhood','Local Authority Area']
df3_N.head()
# Out:
#   PostCode District  PostTown  \
# 0             N81\n  LONDON\n
# 0             N22\n  LONDON\n
# 0             N21\n  LONDON\n
# 0             N20\n  LONDON\n
# 0             N19\n  LONDON\n
#
#                                         Neighborhood Local Authority Area
# 0                        Electoral Reform Services\n     non-geographic\n
# 0  Wood Green district: Wood Green, Bounds Green ...  Haringey, Enfield\n
# 0  Winchmore Hill district: Winchmore Hill, Bush ...            Enfield\n
# 0  Whetstone district: Whetstone, Totteridge, Oak...             Barnet\n
# 0  Upper Holloway district: Upper Holloway, Archw...  Islington, Camden\n

# %% [markdown]
# #### Remove the line Breaks from each column

# %%
df3_N.replace({  '\n' : ''}, regex=True, inplace=True)
df3_N.shape
# Out:
# (27, 4)

# %% [markdown]
# # Dataframe setup for London North West

# %%
#table = soup.table
df3_NW=df_NW
table = soup_NW.find("table",{"class":"wikitable sortable"})
table_rows = table.find_all('tr')
for tr in table_rows:
    td = tr.find_all('td')
    th = tr.find_all('th')
    row_NW = [i.text for i in td] 
    row1_NW = [i.text for i in th]
    df_NW =  pd.DataFrame(data= row1_NW ,dtype='str').transpose()
    df1_NW = pd.DataFrame(data= row_NW ,dtype='str').transpose()
    
    #df2 = pd.array([df , df1])
    df2_NW = pd.concat([df_NW, df1_NW], axis=1, ignore_index=True)
    df3_NW = pd.concat([df2_NW,df3_NW])
df3_NW.head()
# Out:
#         0         1                                                  2  \
# 0  NW26\n  LONDON\n                              PO boxes in NW10[4]\n
# 0  NW11\n  LONDON\n  Golders Green district: Golders Green, Temple ...
# 0  NW10\n  LONDON\n  Willesden district: Willesden, Harlesden, Kens...
# 0   NW9\n  LONDON\n  The Hyde district: The Hyde, Colindale, Kingsb...
# 0   NW8\n  LONDON\n  St John's Wood district: St John's Wood, Primr...
#
#                                                    3
# 0                                   non-geographic\n
# 0                                           Barnet\n
# 0  Brent, Ealing, Hammersmith and Fulham, Kensing...
# 0                            Barnet, Brent, Harrow\n
# 0                              Westminster, Camden\n

# %% [markdown]
# #### Insert column header to the data frame

# %%
df3_NW.columns=['PostCode District', 'PostTown','Neighborhood','Local Authority Area']
df3_NW.head()
# Out:
#   PostCode District  PostTown  \
# 0            NW26\n  LONDON\n
# 0            NW11\n  LONDON\n
# 0            NW10\n  LONDON\n
# 0             NW9\n  LONDON\n
# 0             NW8\n  LONDON\n
#
#                                         Neighborhood  \
# 0                              PO boxes in NW10[4]\n
# 0  Golders Green district: Golders Green, Temple ...
# 0  Willesden district: Willesden, Harlesden, Kens...
# 0  The Hyde district: The Hyde, Colindale, Kingsb...
# 0  St John's Wood district: St John's Wood, Primr...
#
#                                 Local Authority Area
# 0                                   non-geographic\n
# 0                                           Barnet\n
# 0  Brent, Ealing, Hammersmith and Fulham, Kensing...
# 0                            Barnet, Brent, Harrow\n
# 0                              Westminster, Camden\n

# %% [markdown]
# #### Remove the line Breaks from each column

# %%
df3_NW.replace({  '\n' : ''}, regex=True, inplace=True)
df3_NW.shape
# Out:
# (15, 4)

# %% [markdown]
# # Dataframe setup for London South East

# %%
#table = soup.table
df3_SE=df_SE
table = soup_SE.find("table",{"class":"wikitable sortable"})
table_rows = table.find_all('tr')
for tr in table_rows:
    td = tr.find_all('td')
    th = tr.find_all('th')
    row_SE = [i.text for i in td] 
    row1_SE = [i.text for i in th]
    df_SE =  pd.DataFrame(data= row1_SE ,dtype='str').transpose()
    df1_SE = pd.DataFrame(data= row_SE ,dtype='str').transpose()
    
    #df2 = pd.array([df , df1])
    df2_SE = pd.concat([df_SE, df1_SE], axis=1, ignore_index=True)
    df3_SE = pd.concat([df2_SE,df3_SE])
df3_SE.head()
# Out:
#         0         1                                                  2  \
# 0  SE28\n  LONDON\n                  Thamesmead district: Thamesmead\n
# 0  SE27\n  LONDON\n  West Norwood district: West Norwood, Gipsy Hil...
# 0  SE26\n  LONDON\n  Sydenham district: Sydenham, Crystal Palace (p...
# 0  SE25\n  LONDON\n  South Norwood district: South Norwood, Selhurs...
# 0  SE24\n  LONDON\n  Herne Hill district: Herne Hill, Tulse Hill (p...
#
#                                 3
# 0             Bexley, Greenwich\n
# 0                       Lambeth\n
# 0  Bromley, Lewisham, Southwark\n
# 0                       Croydon\n
# 0            Lambeth, Southwark\n

# %% [markdown]
# #### Insert column header to the data frame

# %%
df3_SE.columns=['PostCode District', 'PostTown','Neighborhood','Local Authority Area']
df3_SE.head()
# Out:
#   PostCode District  PostTown  \
# 0            SE28\n  LONDON\n
# 0            SE27\n  LONDON\n
# 0            SE26\n  LONDON\n
# 0            SE25\n  LONDON\n
# 0            SE24\n  LONDON\n
#
#                                         Neighborhood  \
# 0                  Thamesmead district: Thamesmead\n
# 0  West Norwood district: West Norwood, Gipsy Hil...
# 0  Sydenham district: Sydenham, Crystal Palace (p...
# 0  South Norwood district: South Norwood, Selhurs...
# 0  Herne Hill district: Herne Hill, Tulse Hill (p...
#
#              Local Authority Area
# 0             Bexley, Greenwich\n
# 0                       Lambeth\n
# 0  Bromley, Lewisham, Southwark\n
# 0                       Croydon\n
# 0            Lambeth, Southwark\n

# %% [markdown]
# #### Remove the line Breaks from each column

# %%
df3_SE.replace({  '\n' : ''}, regex=True, inplace=True)
df3_SE.shape
# Out:
# (31, 4)

# %% [markdown]
# # Dataframe setup for London South West

# %%
#table = soup.table
df3_SW=df_SW
table = soup_SW.find("table",{"class":"wikitable sortable"})
table_rows = table.find_all('tr')
for tr in table_rows:
    td = tr.find_all('td')
    th = tr.find_all('th')
    row_SW = [i.text for i in td] 
    row1_SW = [i.text for i in th]
    df_SW =  pd.DataFrame(data= row1_SW ,dtype='str').transpose()
    df1_SW = pd.DataFrame(data= row_SW ,dtype='str').transpose()
    
    #df2 = pd.array([df , df1])
    df2_SW = pd.concat([df_SW, df1_SW], axis=1, ignore_index=True)
    df3_SW = pd.concat([df2_SW,df3_SW])
df3_SW.head()
# Out:
#         0         1                                                  2  \
# 0  SW20\n  LONDON\n  West Wimbledon district: Raynes Park, Lower Mo...
# 0  SW19\n  LONDON\n  Wimbledon district: Wimbledon, Colliers Wood, ...
# 0  SW18\n  LONDON\n  Wandsworth district: Wandsworth Town, Southfie...
# 0  SW17\n  LONDON\n        Tooting district: Tooting, Mitcham (part)\n
# 0  SW16\n  LONDON\n  Streatham district: Streatham, Streatham Commo...
#
#                                         3
# 0                                Merton\n
# 0                    Merton, Wandsworth\n
# 0                            Wandsworth\n
# 0                    Wandsworth, Merton\n
# 0  Lambeth, Croydon, Wandsworth, Merton\n

# %% [markdown]
# #### Insert column header to the data frame

# %%
df3_SW.columns=['PostCode District', 'PostTown','Neighborhood','Local Authority Area']
df3_SW.head()
# Out:
#   PostCode District  PostTown  \
# 0            SW20\n  LONDON\n
# 0            SW19\n  LONDON\n
# 0            SW18\n  LONDON\n
# 0            SW17\n  LONDON\n
# 0            SW16\n  LONDON\n
#
#                                         Neighborhood  \
# 0  West Wimbledon district: Raynes Park, Lower Mo...
# 0  Wimbledon district: Wimbledon, Colliers Wood, ...
# 0  Wandsworth district: Wandsworth Town, Southfie...
# 0        Tooting district: Tooting, Mitcham (part)\n
# 0  Streatham district: Streatham, Streatham Commo...
#
#                      Local Authority Area
# 0                                Merton\n
# 0                    Merton, Wandsworth\n
# 0                            Wandsworth\n
# 0                    Wandsworth, Merton\n
# 0  Lambeth, Croydon, Wandsworth, Merton\n

# %% [markdown]
# #### Remove the line Breaks from each column

# %%
df3_SW.replace({  '\n' : ''}, regex=True, inplace=True)
df3_SW.shape
# Out:
# (29, 4)

# %% [markdown]
# # Dataframe setup for London West

# %%
#table = soup.table
df3_W=df_W
table = soup_W.find("table",{"class":"wikitable sortable"})
table_rows = table.find_all('tr')
for tr in table_rows:
    td = tr.find_all('td')
    th = tr.find_all('th')
    row_W = [i.text for i in td] 
    row1_W = [i.text for i in th]
    df_W =  pd.DataFrame(data= row1_W ,dtype='str').transpose()
    df1_W = pd.DataFrame(data= row_W ,dtype='str').transpose()
    
    #df2 = pd.array([df , df1])
    df2_W = pd.concat([df_W, df1_W], axis=1, ignore_index=True)
    df3_W = pd.concat([df2_W,df3_W])
df3_W.head()
# Out:
#        0         1                                                  2  \
# 0  W14\n  LONDON\n  West Kensington district: West Kensington, Ken...
# 0  W13\n  LONDON\n  West Ealing district: West Ealing, Northfields...
# 0  W12\n  LONDON\n  Shepherds Bush district: Shepherds Bush, White...
# 0  W11\n  LONDON\n  Notting Hill district: Notting Hill, Ladbroke ...
# 0  W10\n  LONDON\n  North Kensington district: North Kensington, K...
#
#                                                    3
# 0   Hammersmith and Fulham, Kensington and Chelsea\n
# 0                                           Ealing\n
# 0                           Hammersmith and Fulham\n
# 0  Kensington and Chelsea, Westminster, Hammersmi...
# 0  Kensington and Chelsea, Westminster, Hammersmi...

# %% [markdown]
# #### Insert column header to the data frame

# %%
df3_W.columns=['PostCode District', 'PostTown','Neighborhood','Local Authority Area']
df3_W.head()
# Out:
#   PostCode District  PostTown  \
# 0             W14\n  LONDON\n
# 0             W13\n  LONDON\n
# 0             W12\n  LONDON\n
# 0             W11\n  LONDON\n
# 0             W10\n  LONDON\n
#
#                                         Neighborhood  \
# 0  West Kensington district: West Kensington, Ken...
# 0  West Ealing district: West Ealing, Northfields...
# 0  Shepherds Bush district: Shepherds Bush, White...
# 0  Notting Hill district: Notting Hill, Ladbroke ...
# 0  North Kensington district: North Kensington, K...
#
#                                 Local Authority Area
# 0   Hammersmith and Fulham, Kensington and Chelsea\n
# 0                                           Ealing\n
# 0                           Hammersmith and Fulham\n
# 0  Kensington and Chelsea, Westminster, Hammersmi...
# 0  Kensington and Chelsea, Westminster, Hammersmi...

# %% [markdown]
# #### Remove the line Breaks from each column

# %%
df3_W.replace({  '\n' : ''}, regex=True, inplace=True)
df3_W.shape
# Out:
# (28, 4)

# %% [markdown]
# # Dataframe setup for London West Central

# %%
#table = soup.table
df3_WC=df_WC
table = soup_WC.find("table",{"class":"wikitable sortable"})
table_rows = table.find_all('tr')
for tr in table_rows:
    td = tr.find_all('td')
    th = tr.find_all('th')
    row_WC = [i.text for i in td] 
    row1_WC = [i.text for i in th]
    df_WC =  pd.DataFrame(data= row1_WC ,dtype='str').transpose()
    df1_WC = pd.DataFrame(data= row_WC ,dtype='str').transpose()
    
    #df2 = pd.array([df , df1])
    df2_WC = pd.concat([df_WC, df1_WC], axis=1, ignore_index=True)
    df3_WC = pd.concat([df2_WC,df3_WC])
df3_WC.head()
# Out:
#         0         1                                2                      3
# 0  WC2R\n  LONDON\n  Somerset House, Temple (west)\n          Westminster\n
# 0  WC2N\n  LONDON\n                  Charing Cross\n          Westminster\n
# 0  WC2H\n  LONDON\n    Leicester Square, St. Giles\n  Camden, Westminster\n
# 0  WC2E\n  LONDON\n                  Covent Garden\n          Westminster\n
# 0  WC2B\n  LONDON\n  Drury Lane, Kingsway, Aldwych\n  Camden, Westminster\n

# %% [markdown]
# #### Insert column header to the data frame

# %%
df3_WC.columns=['PostCode District', 'PostTown','Neighborhood','Local Authority Area']
df3_WC.head()
# Out:
#   PostCode District  PostTown                     Neighborhood  \
# 0            WC2R\n  LONDON\n  Somerset House, Temple (west)\n
# 0            WC2N\n  LONDON\n                  Charing Cross\n
# 0            WC2H\n  LONDON\n    Leicester Square, St. Giles\n
# 0            WC2E\n  LONDON\n                  Covent Garden\n
# 0            WC2B\n  LONDON\n  Drury Lane, Kingsway, Aldwych\n
#
#     Local Authority Area
# 0          Westminster\n
# 0          Westminster\n
# 0  Camden, Westminster\n
# 0          Westminster\n
# 0  Camden, Westminster\n

# %% [markdown]
# #### Remove the line Breaks from each column

# %%
df3_WC.replace({  '\n' : ''}, regex=True, inplace=True)
df3_WC.shape
# Out:
# (16, 4)

# %% [markdown]
# # Concatenating the dataframes for all regions in london

# %%
pdList = [df3_E,df3_EC,df3_N,df3_NW,df3_SE,df3_SW,df3_W,df3_WC]
df3= pd.concat(pdList)
#df3

# %% [markdown]
# #### Cleaning the data Frame

# %%
# droping the column names inside the data frame
df3 = df3[df3.Neighborhood != 'Coverage']
#Droping records labeled as NaN
df3=df3.dropna(how='any') 
df3
jd=df3['PostCode District']
#df3

# %% [markdown]
# ## Load the excel file UK postcodes to read the data for each postcode district along with latitude and longitude

# %%
df4=pd.read_csv("ukpostcodes.csv")
df4.head()
# Out:
#    id  postcode   latitude  longitude
# 0   1  AB10 1XG  57.144165  -2.114848
# 1   2  AB10 6RN  57.137880  -2.121487
# 2   3  AB10 7JB  57.124274  -2.127190
# 3   4  AB11 5QN  57.142701  -2.093295
# 4   5  AB11 6UL  57.137547  -2.112233

# %% [markdown]
# #### Derive the postcode district from Postcode

# %%
df4['PostCode District'] = df4['postcode'].str[:4]

# %%
regstr = '|'.join(jd)
df4=df4[df4['PostCode District'].str.upper().str.contains(regstr)]

# %%
df4.shape
# Out:
# (372136, 5)

# %% [markdown]
# #### Drop the unwanted columns of id and postcode

# %%
df4=df4.drop(['postcode','id'], axis=1)
df4.head()
# Out:
#        latitude  longitude PostCode District
# 1543  60.225522  -1.573860              ZE2
# 1544  60.220492  -1.605311              ZE2
# 1545  60.240982  -1.647017              ZE2
# 1546  60.225056  -1.557837              ZE2
# 1547  60.225420  -1.570269              ZE2

# %%
df4 = df4.groupby(['PostCode District'])['latitude','longitude'].mean()

# %%
df4=df4.reset_index()
df4.head()
# Out:
#   PostCode District   latitude  longitude
# 0              BN1   50.841990  -0.139521
# 1              BN10  50.795908   0.001048
# 2              BN11  50.813577  -0.376926
# 3              BN12  50.813982  -0.429238
# 4              BN13  50.832336  -0.410567

# %%
df5=pd.merge(df4, df3, on='PostCode District', how='inner')
df5.head()
# Out:
#   PostCode District   latitude  longitude PostTown  \
# 0              EC1A  51.521118  -0.105546   LONDON
# 1              EC1M  51.521406  -0.102435   LONDON
# 2              EC1N  51.520027  -0.108930   LONDON
# 3              EC1P  51.524502  -0.112088   LONDON
# 4              EC1R  51.524967  -0.108433   LONDON
#
#                        Neighborhood               Local Authority Area
# 0         St Bartholomew's Hospital          City of London, Islington
# 1           Clerkenwell, Farringdon  Islington, Camden, City of London
# 2                     Hatton Garden             Camden, City of London
# 3                                                       non-geographic
# 4  Finsbury, Finsbury Estate (west)                  Islington, Camden

# %%
df5.to_csv('Geospatial_London_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ## Read the file that has information for population in each PostCode District

# %%
df6=pd.read_csv("London_population.csv")
df6.columns=['PostCode District', 'Population','Percentage_population_by_postcode']
df6.head()
# Out:
#   PostCode District  Population  Percentage_population_by_postcode
# 0                E1       70389                               7.11
# 1               E10       43120                               4.36
# 2               E11       54689                               5.52
# 3               E12       42606                               4.30
# 4               E13       47169                               4.76

# %% [markdown]
# #### Join it with df5 dataframe that contins information for postcode districts along with geometric co-ordinates

# %%
df7=pd.merge(df5, df6, on='PostCode District', how='inner')
df7.head()

#df7=df5.join(other.set_index('key'), on='key')
#df4.dtypes
#df6.("PostCode District").dtype
# Out:
#   PostCode District   latitude  longitude PostTown  \
# 0              EC1A  51.521118  -0.105546   LONDON
# 1              EC1M  51.521406  -0.102435   LONDON
# 2              EC1N  51.520027  -0.108930   LONDON
# 3              EC1R  51.524967  -0.108433   LONDON
# 4              EC1V  51.526695  -0.098121   LONDON
#
#                                Neighborhood  \
# 0                 St Bartholomew's Hospital
# 1                   Clerkenwell, Farringdon
# 2                             Hatton Garden
# 3          Finsbury, Finsbury Estate (west)
# 4  Finsbury (east), Moorfields Eye Hospital
#
#                 Local Authority Area  Population  \
# 0          City of London, Islington         894
# 1  Islington, Camden, City of London        2473
# 2             Camden, City of London        2650
# 3                  Islington, Camden        4885
# 4                 Islington, Hackney       12765
#
#    Percentage_population_by_postcode
# 0                               2.69
# ...

# %% [markdown]
# #### Read the London neighborhood data from CSV

# %%
neighborhoods = pd.read_csv("Geospatial_London_data.csv")
neighborhoods.drop(neighborhoods.columns[neighborhoods.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
neighborhoods.head()
# Out:
#   PostCode District   latitude  longitude PostTown  \
# 0              EC1A  51.521118  -0.105546   LONDON
# 1              EC1M  51.521406  -0.102435   LONDON
# 2              EC1N  51.520027  -0.108930   LONDON
# 3              EC1P  51.524502  -0.112088   LONDON
# 4              EC1R  51.524967  -0.108433   LONDON
#
#                        Neighborhood               Local Authority Area
# 0         St Bartholomew's Hospital          City of London, Islington
# 1           Clerkenwell, Farringdon  Islington, Camden, City of London
# 2                     Hatton Garden             Camden, City of London
# 3                               NaN                     non-geographic
# 4  Finsbury, Finsbury Estate (west)                  Islington, Camden

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of London

# %%
address = 'London, LDN'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of London are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of London are 51.4546664, -0.0370617.

# %% [markdown]
# #### Create a map of London with neighborhoods superimposed on top

# %%
# create map of london using latitude and longitude values
map_London = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, Borough, neighborhood in zip(neighborhoods['latitude'], neighborhoods['longitude'], neighborhoods['Local Authority Area'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, Borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_London)  
    
map_London
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Define the foursquare credential and version

# %%
CLIENT_ID = 'HJKCU2VSHOZUTPWBBYUPB5TVG4M0LTDCGBFRCKMIPLOXFZW1' # your Foursquare ID
CLIENT_SECRET = 'QG3H5EZ0CBRK0BCIZYWOEEOXX410X3MNG5IXMXL40PUS50GC' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

#print('Your credentails:')
#print('CLIENT_ID: ' + CLIENT_ID)
#print('CLIENT_SECRET:' + CLIENT_SECRET)

# %% [markdown]
# #### The code below creates a function for finding the neighborhood venues in London

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### The code below executes the above function for each neighborhood and creates a new dataframe called *London_venues*.

# %%
London_venues = getNearbyVenues(names=df5['Neighborhood'],
                                   latitudes=df5['latitude'],
                                   longitudes=df5['longitude']
                                  )
#
# Out:
# St Bartholomew's Hospital
# Clerkenwell, Farringdon
# Hatton Garden
#
# Finsbury, Finsbury Estate (west)
# Finsbury (east), Moorfields Eye Hospital
# St Luke's, Bunhill Fields
# Shoreditch
# Broadgate, Liverpool Street
# Old Broad Street, Tower 42
#
# Bank of England
# Guildhall
# Barbican
# St Mary Axe, Aldgate
# Lloyd's of London, Fenchurch Street
# Tower Hill, Tower of London
#
# Monument, Billingsgate
# Cornhill, Gracechurch Street, Lombard Street
# Fetter Lane
# St Paul's
# Mansion House
#
# Cannon Street
# Blackfriars
# Temple
# Willesden district: Willesden, Harlesden, Kensal Green, Brent Park, College Park, Stonebridge, North Acton (part), West Twyford, Neasden (south), Old Oak Common, Park Royal (north)
# Golders Green district: Golders Green, Temple Fortune, Hampstead Garden Suburb (west), Hendon (part), Brent Cross (part)
# PO boxes in NW1[4]
# PO boxes in NW10[4]
# Greenwich district: Greenwich, Maze Hill, Greenwich Peninsula
# ...

# %% [markdown]
# #### Let's check the size of the resulting dataframe

# %%
print(London_venues.shape)
London_venues.head()
# Out:
# (5414, 7)
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  St Bartholomew's Hospital              51.521118               -0.105546
# 1  St Bartholomew's Hospital              51.521118               -0.105546
# 2  St Bartholomew's Hospital              51.521118               -0.105546
# 3  St Bartholomew's Hospital              51.521118               -0.105546
# 4  St Bartholomew's Hospital              51.521118               -0.105546
#
#                                   Venue  Venue Latitude  Venue Longitude  \
# 0                      Jerusalem Tavern       51.521735        -0.104170
# 1                   BrewDog Clerkenwell       51.522401        -0.103835
# 2                  The Zetter Townhouse       51.522849        -0.103658
# 3            Scotch Malt Whisky Society       51.519444        -0.106879
# 4  Ten Health & Fitness - Hatton Garden       51.520096        -0.108368
#
#          Venue Category
# 0                   Pub
# ...

# %% [markdown]
# #### Extract the records whose venue category is Restaurent

# %%
l = ['Restaurant']  
regstr1 = '|'.join(l)
London_venues=London_venues[London_venues['Venue Category'].str.contains(regstr1)]
print(London_venues.shape)
London_venues.head()
# Out:
# (1388, 7)
#                  Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 6   St Bartholomew's Hospital              51.521118               -0.105546
# 9   St Bartholomew's Hospital              51.521118               -0.105546
# 16  St Bartholomew's Hospital              51.521118               -0.105546
# 17  St Bartholomew's Hospital              51.521118               -0.105546
# 20  St Bartholomew's Hospital              51.521118               -0.105546
#
#                  Venue  Venue Latitude  Venue Longitude  \
# 6   Iberica Farringdon       51.520833        -0.104727
# 9          Sushi Tetsu       51.523348        -0.104015
# 16                Luca       51.522017        -0.101703
# 17   The Modern Pantry       51.522878        -0.103649
# 20     Comptoir Gascon       51.519270        -0.103192
#
#                 Venue Category
# 6           Spanish Restaurant
# 9             Sushi Restaurant
# 16          Italian Restaurant
# ...

# %% [markdown]
# ## Extracting the number of restaurants for each Neighborhood

# %%
London_restaurent_venues_1=London_venues.groupby(['Neighborhood','Neighborhood Latitude','Neighborhood Longitude'])['Venue Category'].count()
London_restaurent_venues_2 = pd.DataFrame(London_restaurent_venues_1)

#London_restaurent_venues_3=London_restaurent_venues_2.drop(['Neighborhood','Neighborhood Latitude','Neighborhood Longitude'], axis=1)
London_restaurent_venues_2.reset_index(inplace=True)
London_restaurent_venues = London_restaurent_venues_2[London_restaurent_venues_2.Neighborhood != '']
London_restaurent_venues.columns=['Neighborhood','latitude','longitude','Restaurant_Count']
London_restaurent_venues.head(10)
# Out:
#                                          Neighborhood   latitude  longitude  \
# 4   Anerley district: Anerley, Crystal Palace (par...  51.412299  -0.059364
# 5   Balham district: Balham, Clapham South, Wandsw...  51.446305  -0.149193
# 6                                     Bank of England  51.516353  -0.091683
# 7                                            Barbican  51.519522  -0.093892
# 8                             Barnes district: Barnes  51.476309  -0.243405
# 9   Battersea head district: Battersea, Clapham South  51.467968  -0.164021
# 10  Belgravia, Chelsea (part), area between Sloane...  51.492500  -0.150732
# 11  Belgravia, north of Eaton Square, Knightsbridg...  51.498073  -0.156462
# 12                                        Blackfriars  51.512531  -0.099990
# 13        Bloomsbury, British Museum, Southampton Row  51.519518  -0.125812
#
#     Restaurant_Count
# 4                  1
# 5                 11
# 6                 31
# 7                 12
# ...

# %% [markdown]
# #### Join the data frame displayed above with data frame df7 to show the information of population along with the restaurant counts for each neighborhood

# %%
London_restaurent_stats=pd.merge(df7[['PostCode District','latitude','longitude','Population','Percentage_population_by_postcode']], London_restaurent_venues, on=['latitude','longitude'], how='inner')
London_restaurent_stats.head()
# Out:
#   PostCode District   latitude  longitude  Population  \
# 0              EC1A  51.521118  -0.105546         894
# 1              EC1M  51.521406  -0.102435        2473
# 2              EC1N  51.520027  -0.108930        2650
# 3              EC1R  51.524967  -0.108433        4885
# 4              EC1V  51.526695  -0.098121       12765
#
#    Percentage_population_by_postcode  \
# 0                               2.69
# 1                               7.45
# 2                               7.98
# 3                              14.71
# 4                              38.44
#
#                                Neighborhood  Restaurant_Count
# 0                 St Bartholomew's Hospital                24
# 1                   Clerkenwell, Farringdon                20
# 2                             Hatton Garden                28
# 3          Finsbury, Finsbury Estate (west)                24
# 4  Finsbury (east), Moorfields Eye Hospital                14

# %% [markdown]
# #### Sort and arrange the columns in dataframe London_restaurent_stats

# %%
London_restaurent_stats_1=London_restaurent_stats.reindex(columns=['PostCode District','Neighborhood','latitude','longitude','Restaurant_Count','Population','Percentage_population_by_postcode'])
London_restaurent_stats=London_restaurent_stats_1.sort_values(['Population','Restaurant_Count'], ascending=False)
London_restaurent_stats.head()
# Out:
#    PostCode District                                       Neighborhood  \
# 37              SW16  Streatham district: Streatham, Streatham Commo...
# 40              SW19  Wimbledon district: Wimbledon, Colliers Wood, ...
# 21              SE18  Woolwich district: Woolwich, Royal Arsenal, Pl...
# 33              SW11  Battersea head district: Battersea, Clapham South
# 18              SE15  Peckham district: Peckham, Nunhead, South Berm...
#
#      latitude  longitude  Restaurant_Count  Population  \
# 37  51.421370  -0.129253                 1       80927
# 40  51.423924  -0.203416                14       77676
# 21  51.484328   0.072814                 3       77384
# 33  51.467968  -0.164021                 9       71717
# 18  51.472701  -0.065687                 8       64359
#
#     Percentage_population_by_postcode
# 37                               9.25
# 40                               8.88
# 21                               7.83
# 33                               8.20
# ...

# %% [markdown]
# #### Filter the records that have less than 3 Restaurants,Population is less than 20000 and percentage population is less than 5% of postcode district

# %%
London_restaurent_stats_2 = London_restaurent_stats[London_restaurent_stats.Restaurant_Count >= 3]
London_restaurent_stats_3 = London_restaurent_stats_2[London_restaurent_stats.Population >= 20000]
London_restaurent_stats =   London_restaurent_stats_3[London_restaurent_stats.Percentage_population_by_postcode >= 5]
London_restaurent_stats.head(10)
#London_restaurent_stats.iloc['latitude']
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/jupyterlab/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#    PostCode District                                       Neighborhood  \
# 40              SW19  Wimbledon district: Wimbledon, Colliers Wood, ...
# 21              SE18  Woolwich district: Woolwich, Royal Arsenal, Pl...
# 33              SW11  Battersea head district: Battersea, Clapham South
# 18              SE15  Peckham district: Peckham, Nunhead, South Berm...
# 38              SW17          Tooting district: Tooting, Mitcham (part)
# 39              SW18  Wandsworth district: Wandsworth Town, Southfie...
# 12              NW11  Golders Green district: Golders Green, Temple ...
#
# ...

# %% [markdown]
# #### Mark the place on the map of London to find a location in center where the restaurent can be open

# %%
# create map of london using latitude and longitude values
map_London_restaurent_stats = folium.Map(location=[51.472701, -0.065687	], zoom_start=12)

# add markers to map
for lat, lng, London_restaurent_stats in zip(London_restaurent_stats['latitude'], London_restaurent_stats['longitude'],  London_restaurent_stats['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_London_restaurent_stats)  
    

    
map_London_restaurent_stats
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
